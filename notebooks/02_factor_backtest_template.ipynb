# %% [markdown]
# # 因子与模拟交易模板
#
# 这个模板只做本地研究模拟，不连接真实交易。

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / 'pyproject.toml').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
from futures_workflow.research_platform import ResearchPlatformRunner

runner = ResearchPlatformRunner(project_root=ROOT, normalized_root=ROOT / 'data' / 'normalized', platform_dir=ROOT / 'data' / 'normalized' / 'platform')

# %%
runner.run_research(date_value='latest', dataset='daily_ohlcv')

# %%
# 根据本地已有历史日期修改 start/end
runner.run_strategy_backtest(start_date='2026-04-16', end_date='2026-04-16', strategy='momentum')
