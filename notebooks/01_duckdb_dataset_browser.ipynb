# %% [markdown]
# # DuckDB 数据集浏览模板
#
# 用于查看本地 DuckDB manifest 和任一 normalized 数据集。

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / 'pyproject.toml').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'examples'))
from research_helpers import list_datasets, preview_dataset

list_datasets()[:10]

# %%
preview_dataset('daily_ohlcv', limit=20)
